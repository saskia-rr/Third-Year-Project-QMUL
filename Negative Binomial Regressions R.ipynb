# %% [markdown]
# # Conducting Exploratory Data Analysis and Regression to Investigate the Relationship between Suicide and the Economy: Using coding language R

# %% [markdown]
# ## Chapter 3.2: Negative Binomial Regression

# %%
#Loading in the Dataframe
urlfile <- "https://raw.githubusercontent.com/sas-hub/Project/main/europedfcsvclean.csv"
df <- read.csv(url(urlfile))

# %%
#Loading in the reqired packages
library(plyr)
library(dplyr)
require(ggplot2)
require(MASS)

# %%
#Summary of the dataframe
summary(df)
# Out:
#        X            country           year          sex
#  Min.   :    0   Austria:  372   Min.   :1985   female:6966
#  1st Qu.: 3533   Belgium:  372   1st Qu.:1995   male  :6966
#  Median : 7036   Greece :  372   Median :2002
#  Mean   : 7032   Iceland:  372   Mean   :2002
#  3rd Qu.:10538   Israel :  372   3rd Qu.:2009
#  Max.   :14041   Italy  :  372   Max.   :2015
#                  (Other):11700
#           age        suicides_no        population       suicides.100k.pop
#  15-24 years:2322   Min.   :    0.0   Min.   :     721   Min.   :  0.000
#  25-34 years:2322   1st Qu.:    7.0   1st Qu.:  251000   1st Qu.:  2.280
#  35-54 years:2322   Median :   45.0   Median :  551015   Median :  8.225
#  5-14 years :2322   Mean   :  257.3   Mean   : 1494520   Mean   : 16.041
#  55-74 years:2322   3rd Qu.:  171.0   3rd Qu.: 1406075   3rd Qu.: 20.552
#  75+ years  :2322   Max.   :22338.0   Max.   :23046634   Max.   :177.610
#
#       country.year   gdp_for_year....    gdp_per_capita....
#  Albania1987:   12   Min.   :7.095e+08   Min.   :   251
#  Albania1988:   12   1st Qu.:1.730e+10   1st Qu.:  3829
#  Albania1989:   12   Median :8.146e+10   Median : 14479
#  Albania1992:   12   Mean   :3.463e+11   Mean   : 20776
#  Albania1993:   12   3rd Qu.:3.014e+11   3rd Qu.: 30066
#  Albania1994:   12   Max.   :3.891e+12   Max.   :126352
#  (Other)    :13860
#            generation      region           HDI
#  Boomers        :2510   Europe:13932   Min.   :0.5850
#  G.I. Generation:1304                  1st Qu.:0.7560
#  Generation X   :3182                  Median :0.8230
#  Generation Z   : 764                  Mean   :0.8096
#  Millenials     :2990                  3rd Qu.:0.8710
#  Silent         :3182                  Max.   :0.9480
#                                        NA's   :2701

# %%
#Clean data to remove any rows that dont have the HDI value
HDIdata <- df[complete.cases(df),]

# %% [markdown]
# #### GDP per Capita Negative Binomial Regression

# %%
#Load the model
summary(m1 <- glm.nb(suicides_no ~ gdp_per_capita...., data = df))
# Out:
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = df,
#     init.theta = 0.3093478556, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0879  -1.2758  -0.7406  -0.1669   6.1330
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.876e+00  2.133e-02   275.4   <2e-16 ***
# gdp_per_capita.... -1.834e-05  7.190e-07   -25.5   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.3093) family taken to be 1)
#
#     Null deviance: 18472  on 13931  degrees of freedom
# Residual deviance: 18002  on 13930  degrees of freedom
# AIC: 162308
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.30935
#           Std. Err.:  0.00313
#
#  2 x log-likelihood:  -162302.34000

# %%
#Making the respective Poisson model to compare with the negative binomial using
#the Log-Likelihood
m2 <- glm(suicides_no ~ gdp_per_capita.... , family = "poisson", data = df)
pchisq(2 * (logLik(m1) - logLik(m2)), df = 1, lower.tail = FALSE)
# Out:
# 'log Lik.' 0 (df=3)

# %%
# Getting the coefficients and exponentiating them so the Incident Rate Ratio 
#can be found
(est <- cbind(Estimate = coef(m1),confint(m1)))

exp(est)
# Out:
# Waiting for profiling to be done...
#                    Estimate      2.5 %         97.5 %
# (Intercept)         5.8764942118  5.832731e+00  5.920671e+00
# gdp_per_capita.... -0.0000183373 -1.988193e-05 -1.677457e-05
#                    Estimate    2.5 %       97.5 %
# (Intercept)        356.5570346 341.2895320 372.6617941
# gdp_per_capita....   0.9999817   0.9999801   0.9999832

# %% [markdown]
# #### HDI Negative Binomial Regression

# %%
#Load the model
summary(m3 <- glm.nb(suicides_no ~ HDI, data = df))
# Out:
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = df, init.theta = 0.3492180778,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1250  -1.2885  -0.6556  -0.0589   3.7830
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   5.8886     0.1648  35.732  < 2e-16 ***
# HDI          -0.8156     0.2026  -4.025 5.69e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.3492) family taken to be 1)
#
#     Null deviance: 14321  on 11230  degrees of freedom
# Residual deviance: 14305  on 11229  degrees of freedom
#   (2701 observations deleted due to missingness)
# AIC: 128649
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.34922
#           Std. Err.:  0.00399
#
#  2 x log-likelihood:  -128642.69600

# %%
#Making the respective Poisson model to compare with the negative binomial using
#the Log-Likelihood
m4 <- glm(suicides_no ~ HDI , family = "poisson", data = df)

pchisq(2 * (logLik(m3) - logLik(m4)), df = 1, lower.tail = FALSE)
# Out:
# 'log Lik.' 0 (df=3)

# %%
# Getting the coefficients and exponentiating them so the Incident Rate Ratio 
#can be found
(est2 <- cbind(Estimate = coef(m3),confint(m3)))

exp(est2)
# Out:
# Waiting for profiling to be done...
#             Estimate  2.5 %     97.5 %
# (Intercept)  5.888608  5.559474  6.220210
# HDI         -0.815554 -1.222739 -0.410234
#             Estimate    2.5 %       97.5 %
# (Intercept) 360.9023786 259.6862900 502.808772
# HDI           0.4423942   0.2944227   0.663495

# %% [markdown]
# #### Negative Binomial by country for GDP per Capita

# %%
# Fitting the Negative binomial regression model by country using GDP per Capita
#as the independent variable
by(df,df$country,function(x) summary(glm.nb(suicides_no ~ gdp_per_capita.... , data = x)))

#As so many of the models are statistically insignificant, 
#not going to check the model assumptions as its evident it's not a good fit.
# Out:
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
# df$country: Albania
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6529127489, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8280  -1.1267  -0.3085   0.3671   1.8124
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         2.059e+00  1.329e-01  15.491   <2e-16 ***
# gdp_per_capita.... -2.667e-05  5.744e-05  -0.464    0.642
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6529) family taken to be 1)
#
#     Null deviance: 303.75  on 263  degrees of freedom
# Residual deviance: 303.54  on 262  degrees of freedom
# AIC: 1610.4
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6529
#           Std. Err.:  0.0659
#
#  2 x log-likelihood:  -1604.3690
# ------------------------------------------------------------
# df$country: Armenia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.8963091468, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9752  -1.1178  -0.4394   0.3507   1.8592
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         1.971e+00  1.027e-01  19.181   <2e-16 ***
# gdp_per_capita.... -6.788e-05  4.381e-05  -1.549    0.121
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8963) family taken to be 1)
#
#     Null deviance: 332.3  on 287  degrees of freedom
# Residual deviance: 329.9  on 286  degrees of freedom
# AIC: 1688.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8963
#           Std. Err.:  0.0892
#
#  2 x log-likelihood:  -1682.6830
# ------------------------------------------------------------
# df$country: Austria
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7391020807, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8138  -1.0115  -0.1415   0.2634   1.3121
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.271e+00  1.681e-01  31.359  < 2e-16 ***
# gdp_per_capita.... -1.194e-05  4.625e-06  -2.581  0.00986 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7391) family taken to be 1)
#
#     Null deviance: 449.79  on 371  degrees of freedom
# Residual deviance: 443.08  on 370  degrees of freedom
# AIC: 4350.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7391
#           Std. Err.:  0.0491
#
#  2 x log-likelihood:  -4344.7990
# ------------------------------------------------------------
# df$country: Azerbaijan
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7687799264, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9795  -0.9857  -0.4066   0.1989   2.9036
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         2.248e+00  1.319e-01  17.045   <2e-16 ***
# gdp_per_capita.... -9.565e-05  1.002e-04  -0.954     0.34
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7688) family taken to be 1)
#
#     Null deviance: 221.39  on 191  degrees of freedom
# Residual deviance: 220.74  on 190  degrees of freedom
# AIC: 1232.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7688
#           Std. Err.:  0.0859
#
#  2 x log-likelihood:  -1226.3390
# ------------------------------------------------------------
# df$country: Belarus
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6593839894, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2949  -1.0532  -0.4286   0.2345   1.8528
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.675e+00  1.272e-01  44.603   <2e-16 ***
# gdp_per_capita.... -6.530e-05  3.024e-05  -2.159   0.0308 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6594) family taken to be 1)
#
#     Null deviance: 308.64  on 251  degrees of freedom
# Residual deviance: 304.27  on 250  degrees of freedom
# AIC: 3228.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6594
#           Std. Err.:  0.0505
#
#  2 x log-likelihood:  -3222.7560
# ------------------------------------------------------------
# df$country: Belgium
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7461183984, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8536  -0.9695  -0.1323   0.2734   1.5707
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.192e+00  1.676e-01  30.980   <2e-16 ***
# gdp_per_capita.... -2.015e-06  4.879e-06  -0.413     0.68
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7461) family taken to be 1)
#
#     Null deviance: 443.39  on 371  degrees of freedom
# Residual deviance: 443.22  on 370  degrees of freedom
# AIC: 4546
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7461
#           Std. Err.:  0.0490
#
#  2 x log-likelihood:  -4540.0160
# ------------------------------------------------------------
# df$country: Bosnia and Herzegovina
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.5916208665, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1229  -0.7943  -0.7943   0.1116   1.2665
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -7000.2823  1178.7179  -5.939 2.87e-09 ***
# gdp_per_capita....     1.3789     0.2321   5.941 2.84e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5916) family taken to be 1)
#
#     Null deviance: 55.666  on 23  degrees of freedom
# Residual deviance: 22.883  on 22  degrees of freedom
# AIC: 127.23
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.592
#           Std. Err.:  0.224
#
#  2 x log-likelihood:  -121.228
# ------------------------------------------------------------
# df$country: Bulgaria
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.84093651, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8869  -1.1277  -0.2529   0.4099   1.5010
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.933e+00  1.024e-01  48.176  < 2e-16 ***
# gdp_per_capita.... -9.416e-05  2.327e-05  -4.047 5.19e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8409) family taken to be 1)
#
#     Null deviance: 439.36  on 359  degrees of freedom
# Residual deviance: 424.01  on 358  degrees of freedom
# AIC: 4028
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8409
#           Std. Err.:  0.0572
#
#  2 x log-likelihood:  -4022.0250
# ------------------------------------------------------------
# df$country: Croatia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7176542831, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6009  -1.1399  -0.2554   0.1568   1.3583
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.503e+00  2.024e-01  22.248   <2e-16 ***
# gdp_per_capita.... -2.474e-05  1.835e-05  -1.348    0.178
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7177) family taken to be 1)
#
#     Null deviance: 301.91  on 251  degrees of freedom
# Residual deviance: 300.08  on 250  degrees of freedom
# AIC: 2637.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7177
#           Std. Err.:  0.0586
#
#  2 x log-likelihood:  -2631.5110
# ------------------------------------------------------------
# df$country: Cyprus
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.5476074074, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.5489  -1.2613  -0.5565   0.2291   2.1066
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.646e+00  5.502e-01  -2.991  0.00278 **
# gdp_per_capita....  8.359e-05  1.855e-05   4.507 6.58e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5476) family taken to be 1)
#
#     Null deviance: 183.21  on 167  degrees of freedom
# Residual deviance: 166.10  on 166  degrees of freedom
# AIC: 642.04
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5476
#           Std. Err.:  0.0952
#
#  2 x log-likelihood:  -636.0440
# ------------------------------------------------------------
# df$country: Czech Republic
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6884909465, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7223  -1.1069  -0.2399   0.1393   1.6176
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.044e+00  1.351e-01  37.337   <2e-16 ***
# gdp_per_capita.... -1.124e-05  9.599e-06  -1.171    0.242
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6885) family taken to be 1)
#
#     Null deviance: 375.67  on 311  degrees of freedom
# Residual deviance: 374.28  on 310  degrees of freedom
# AIC: 3664.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6885
#           Std. Err.:  0.0491
#
#  2 x log-likelihood:  -3658.8620
# ------------------------------------------------------------
# df$country: Denmark
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6745220697, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4974  -1.0582  -0.2581   0.2132   1.5093
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.533e+00  2.932e-01  15.457   <2e-16 ***
# gdp_per_capita.... -9.764e-06  5.750e-06  -1.698   0.0895 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6745) family taken to be 1)
#
#     Null deviance: 320.25  on 263  degrees of freedom
# Residual deviance: 317.33  on 262  degrees of freedom
# AIC: 2652.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6745
#           Std. Err.:  0.0555
#
#  2 x log-likelihood:  -2646.7980
# ------------------------------------------------------------
# df$country: Estonia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7207864676, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4070  -1.1627  -0.3366   0.1635   2.0716
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         3.830e+00  1.510e-01  25.363  < 2e-16 ***
# gdp_per_capita.... -4.852e-05  1.156e-05  -4.196 2.72e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7208) family taken to be 1)
#
#     Null deviance: 316.13  on 251  degrees of freedom
# Residual deviance: 297.98  on 250  degrees of freedom
# AIC: 2156.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7208
#           Std. Err.:  0.0624
#
#  2 x log-likelihood:  -2150.6920
# ------------------------------------------------------------
# df$country: Finland
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.667679063, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6305  -0.9856  -0.3140   0.2247   1.6950
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.044e+00  2.058e-01  24.512   <2e-16 ***
# gdp_per_capita.... -1.366e-05  5.499e-06  -2.484    0.013 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6677) family taken to be 1)
#
#     Null deviance: 424.62  on 347  degrees of freedom
# Residual deviance: 418.53  on 346  degrees of freedom
# AIC: 3841.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6677
#           Std. Err.:  0.0460
#
#  2 x log-likelihood:  -3835.1910
# ------------------------------------------------------------
# df$country: France
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7165566012, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6709  -1.0696  -0.1761   0.2992   1.4582
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         7.002e+00  1.892e-01  37.002   <2e-16 ***
# gdp_per_capita.... -5.924e-06  5.677e-06  -1.044    0.297
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7166) family taken to be 1)
#
#     Null deviance: 433.36  on 359  degrees of freedom
# Residual deviance: 432.27  on 358  degrees of freedom
# AIC: 5604.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7166
#           Std. Err.:  0.0459
#
#  2 x log-likelihood:  -5598.2610
# ------------------------------------------------------------
# df$country: Georgia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7914935589, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1057  -1.1616  -0.4346   0.3574   1.8300
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         2.505e+00  1.256e-01  19.946   <2e-16 ***
# gdp_per_capita.... -1.555e-06  5.460e-05  -0.028    0.977
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7915) family taken to be 1)
#
#     Null deviance: 307.24  on 263  degrees of freedom
# Residual deviance: 307.24  on 262  degrees of freedom
# AIC: 1869.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7915
#           Std. Err.:  0.0728
#
#  2 x log-likelihood:  -1863.6970
# ------------------------------------------------------------
# df$country: Germany
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7195224281, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4814  -1.1457  -0.1623   0.2272   1.3129
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         7.227e+00  2.779e-01  26.003   <2e-16 ***
# gdp_per_capita.... -1.116e-05  7.672e-06  -1.455    0.146
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7195) family taken to be 1)
#
#     Null deviance: 376.68  on 311  degrees of freedom
# Residual deviance: 374.56  on 310  degrees of freedom
# AIC: 4869.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7195
#           Std. Err.:  0.0495
#
#  2 x log-likelihood:  -4863.8490
# ------------------------------------------------------------
# df$country: Greece
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6894252238, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3376  -0.9928  -0.3155   0.3178   1.7710
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        3.431e+00  1.515e-01  22.646   <2e-16 ***
# gdp_per_capita.... 4.239e-06  8.092e-06   0.524      0.6
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6894) family taken to be 1)
#
#     Null deviance: 446.89  on 371  degrees of freedom
# Residual deviance: 446.62  on 370  degrees of freedom
# AIC: 3339.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6894
#           Std. Err.:  0.0499
#
#  2 x log-likelihood:  -3333.3250
# ------------------------------------------------------------
# df$country: Hungary
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.581459521, link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.68418  -1.14143  -0.24194   0.05925   1.53922
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.850e+00  1.737e-01  33.678   <2e-16 ***
# gdp_per_capita.... -4.172e-05  1.693e-05  -2.465   0.0137 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5815) family taken to be 1)
#
#     Null deviance: 373.29  on 299  degrees of freedom
# Residual deviance: 367.15  on 298  degrees of freedom
# AIC: 3820.1
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5815
#           Std. Err.:  0.0415
#
#  2 x log-likelihood:  -3814.1200
# ------------------------------------------------------------
# df$country: Iceland
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.8636013909, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6526  -1.5666  -0.3080   0.4444   1.8428
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        8.856e-01  1.815e-01   4.878 1.07e-06 ***
# gdp_per_capita.... 4.330e-06  4.382e-06   0.988    0.323
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8636) family taken to be 1)
#
#     Null deviance: 415.58  on 371  degrees of freedom
# Residual deviance: 414.61  on 370  degrees of freedom
# AIC: 1648.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8636
#           Std. Err.:  0.0965
#
#  2 x log-likelihood:  -1642.5800
# ------------------------------------------------------------
# df$country: Ireland
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6732748837, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3916  -1.1715  -0.5213   0.4515   1.6889
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        3.227e+00  1.301e-01  24.798  < 2e-16 ***
# gdp_per_capita.... 9.088e-06  3.289e-06   2.763  0.00573 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6733) family taken to be 1)
#
#     Null deviance: 435.12  on 359  degrees of freedom
# Residual deviance: 427.93  on 358  degrees of freedom
# AIC: 3249.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6733
#           Std. Err.:  0.0474
#
#  2 x log-likelihood:  -3243.8050
# ------------------------------------------------------------
# df$country: Israel
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 1.00257366, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6819  -0.9253  -0.2249   0.4510   1.8608
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        3.208e+00  1.400e-01   22.92   <2e-16 ***
# gdp_per_capita.... 8.739e-06  5.602e-06    1.56    0.119
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(1.0026) family taken to be 1)
#
#     Null deviance: 438.39  on 371  degrees of freedom
# Residual deviance: 436.11  on 370  degrees of freedom
# AIC: 3299.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.0026
#           Std. Err.:  0.0735
#
#  2 x log-likelihood:  -3293.2180
# ------------------------------------------------------------
# df$country: Italy
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7169526958, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.9719  -1.0825  -0.1693   0.3579   1.3849
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         6.024e+00  1.926e-01   31.27   <2e-16 ***
# gdp_per_capita.... -5.768e-06  6.865e-06   -0.84    0.401
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.717) family taken to be 1)
#
#     Null deviance: 445.88  on 371  degrees of freedom
# Residual deviance: 445.17  on 370  degrees of freedom
# AIC: 5089.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7170
#           Std. Err.:  0.0457
#
#  2 x log-likelihood:  -5083.1880
# ------------------------------------------------------------
# df$country: Kazakhstan
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.8724107368, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2339  -1.1906  -0.6315   0.5130   1.9351
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.875e+00  9.012e-02  65.187   <2e-16 ***
# gdp_per_capita.... -1.745e-05  1.250e-05  -1.396    0.163
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8724) family taken to be 1)
#
#     Null deviance: 366.96  on 311  degrees of freedom
# Residual deviance: 365.07  on 310  degrees of freedom
# AIC: 4234.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8724
#           Std. Err.:  0.0611
#
#  2 x log-likelihood:  -4228.8620
# ------------------------------------------------------------
# df$country: Kyrgyzstan
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.9864873378, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7101  -1.1086  -0.5812   0.5581   1.8986
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         3.8327599  0.1244939  30.787   <2e-16 ***
# gdp_per_capita.... -0.0001352  0.0001532  -0.883    0.377
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9865) family taken to be 1)
#
#     Null deviance: 355.57  on 311  degrees of freedom
# Residual deviance: 354.79  on 310  degrees of freedom
# AIC: 2968.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9865
#           Std. Err.:  0.0726
#
#  2 x log-likelihood:  -2962.1980
# ------------------------------------------------------------
# df$country: Latvia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6387860422, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4432  -1.0897  -0.3690   0.1209   1.7450
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.343e+00  1.536e-01  28.270  < 2e-16 ***
# gdp_per_capita.... -5.097e-05  1.471e-05  -3.464 0.000533 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6388) family taken to be 1)
#
#     Null deviance: 314.85  on 251  degrees of freedom
# Residual deviance: 302.52  on 250  degrees of freedom
# AIC: 2442.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6388
#           Std. Err.:  0.0532
#
#  2 x log-likelihood:  -2436.2960
# ------------------------------------------------------------
# df$country: Lithuania
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6529056008, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6327  -1.1129  -0.4042   0.1602   1.7381
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.012e+00  1.528e-01   32.80  < 2e-16 ***
# gdp_per_capita.... -3.903e-05  1.456e-05   -2.68  0.00736 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6529) family taken to be 1)
#
#     Null deviance: 309.73  on 251  degrees of freedom
# Residual deviance: 302.52  on 250  degrees of freedom
# AIC: 2828.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6529
#           Std. Err.:  0.0511
#
#  2 x log-likelihood:  -2822.3060
# ------------------------------------------------------------
# df$country: Luxembourg
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.9041682023, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9148  -1.0896  -0.3227   0.3602   2.0490
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         1.817e+00  1.303e-01  13.954   <2e-16 ***
# gdp_per_capita.... -2.324e-06  1.698e-06  -1.369    0.171
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9042) family taken to be 1)
#
#     Null deviance: 429.34  on 371  degrees of freedom
# Residual deviance: 427.53  on 370  degrees of freedom
# AIC: 2049.1
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9042
#           Std. Err.:  0.0841
#
#  2 x log-likelihood:  -2043.0670
# ------------------------------------------------------------
# df$country: Malta
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.5963174975, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4742  -1.1518  -0.6452   0.3479   2.2453
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -3.811e-01  1.851e-01  -2.059   0.0395 *
# gdp_per_capita....  5.465e-05  1.129e-05   4.841 1.29e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5963) family taken to be 1)
#
#     Null deviance: 381.45  on 371  degrees of freedom
# Residual deviance: 360.06  on 370  degrees of freedom
# AIC: 1240.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5963
#           Std. Err.:  0.0776
#
#  2 x log-likelihood:  -1234.5110
# ------------------------------------------------------------
# df$country: Montenegro
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.2239069988, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4711  -0.8917  -0.6687  -0.4480   2.6268
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -2.6921606  0.5281120  -5.098 3.44e-07 ***
# gdp_per_capita....  0.0007814  0.0001054   7.416 1.21e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.2239) family taken to be 1)
#
#     Null deviance: 124.770  on 119  degrees of freedom
# Residual deviance:  86.124  on 118  degrees of freedom
# AIC: 424.81
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.2239
#           Std. Err.:  0.0463
#
#  2 x log-likelihood:  -418.8140
# ------------------------------------------------------------
# df$country: Netherlands
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.8116821533, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8838  -0.8344  -0.2719   0.4007   1.6825
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        4.839e+00  1.525e-01   31.73   <2e-16 ***
# gdp_per_capita.... 1.157e-06  3.989e-06    0.29    0.772
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8117) family taken to be 1)
#
#     Null deviance: 438.01  on 371  degrees of freedom
# Residual deviance: 437.93  on 370  degrees of freedom
# AIC: 4372.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8117
#           Std. Err.:  0.0538
#
#  2 x log-likelihood:  -4366.7290
# ------------------------------------------------------------
# df$country: Norway
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.9274877076, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7246  -0.9412  -0.2561   0.4000   1.5848
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         3.938e+00  1.194e-01  32.977   <2e-16 ***
# gdp_per_capita.... -1.474e-06  1.848e-06  -0.798    0.425
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9275) family taken to be 1)
#
#     Null deviance: 422.72  on 359  degrees of freedom
# Residual deviance: 422.07  on 358  degrees of freedom
# AIC: 3506.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9275
#           Std. Err.:  0.0663
#
#  2 x log-likelihood:  -3500.9140
# ------------------------------------------------------------
# df$country: Poland
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6409430271, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2551  -1.1557  -0.4667   0.2736   1.7914
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        6.119e+00  1.477e-01  41.434   <2e-16 ***
# gdp_per_capita.... 7.407e-06  1.571e-05   0.471    0.637
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6409) family taken to be 1)
#
#     Null deviance: 351.08  on 287  degrees of freedom
# Residual deviance: 350.86  on 286  degrees of freedom
# AIC: 4097.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6409
#           Std. Err.:  0.0454
#
#  2 x log-likelihood:  -4091.3230
# ------------------------------------------------------------
# df$country: Portugal
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6950290173, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5924  -1.0341  -0.2891   0.3012   1.5469
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        4.113e+00  1.526e-01  26.949   <2e-16 ***
# gdp_per_capita.... 1.340e-05  9.670e-06   1.386    0.166
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.695) family taken to be 1)
#
#     Null deviance: 390.57  on 323  degrees of freedom
# Residual deviance: 388.47  on 322  degrees of freedom
# AIC: 3419.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6950
#           Std. Err.:  0.0505
#
#  2 x log-likelihood:  -3413.5430
# ------------------------------------------------------------
# df$country: Romania
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7247274514, link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.88588  -1.15643  -0.36511   0.00939   1.87558
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.446e+00  1.083e-01  50.272   <2e-16 ***
# gdp_per_capita.... -1.294e-05  1.866e-05  -0.693    0.488
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7247) family taken to be 1)
#
#     Null deviance: 387.69  on 323  degrees of freedom
# Residual deviance: 387.22  on 322  degrees of freedom
# AIC: 4121.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7247
#           Std. Err.:  0.0494
#
#  2 x log-likelihood:  -4115.4640
# ------------------------------------------------------------
# df$country: Russian Federation
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7561621145, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2879  -0.9965  -0.5408   0.4134   1.9580
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         8.501e+00  1.054e-01  80.633  < 2e-16 ***
# gdp_per_capita.... -4.610e-05  1.286e-05  -3.584 0.000338 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7562) family taken to be 1)
#
#     Null deviance: 399.55  on 323  degrees of freedom
# Residual deviance: 387.31  on 322  degrees of freedom
# AIC: 5949.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7562
#           Std. Err.:  0.0510
#
#  2 x log-likelihood:  -5943.2680
# ------------------------------------------------------------
# df$country: San Marino
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 2590.63109, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.4973  -0.4973  -0.4840  -0.4303   1.7160
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)        -1.604e+00  2.488e+00  -0.645    0.519
# gdp_per_capita.... -1.119e-05  4.659e-05  -0.240    0.810
#
# (Dispersion parameter for Negative Binomial(2590.631) family taken to be 1)
#
#     Null deviance: 17.576  on 35  degrees of freedom
# Residual deviance: 17.517  on 34  degrees of freedom
# AIC: 31.518
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  2591
#           Std. Err.:  106991
# Warning while fitting theta: iteration limit reached
#
#  2 x log-likelihood:  -25.518
# ------------------------------------------------------------
# df$country: Serbia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.5727568268, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4844  -1.0354  -0.2081   0.2873   1.1836
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.896e+00  2.292e-01   21.37   <2e-16 ***
# gdp_per_capita.... -4.052e-05  4.713e-05   -0.86     0.39
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5728) family taken to be 1)
#
#     Null deviance: 264.11  on 215  degrees of freedom
# Residual deviance: 263.37  on 214  degrees of freedom
# AIC: 2431.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5728
#           Std. Err.:  0.0508
#
#  2 x log-likelihood:  -2425.8930
# ------------------------------------------------------------
# df$country: Slovakia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.4323709244, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0693  -1.1319  -0.3824   0.0539   1.7869
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.194e+00  1.912e-01  21.929   <2e-16 ***
# gdp_per_capita.... -2.625e-05  1.583e-05  -1.658   0.0974 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.4324) family taken to be 1)
#
#     Null deviance: 322.30  on 263  degrees of freedom
# Residual deviance: 319.47  on 262  degrees of freedom
# AIC: 2482.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.4324
#           Std. Err.:  0.0355
#
#  2 x log-likelihood:  -2476.1590
# ------------------------------------------------------------
# df$country: Slovenia
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.6388676741, link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.36231  -1.05361  -0.30023   0.09147   1.46783
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.148e+00  2.469e-01  16.799   <2e-16 ***
# gdp_per_capita.... -2.240e-05  1.255e-05  -1.785   0.0743 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6389) family taken to be 1)
#
#     Null deviance: 305.26  on 251  degrees of freedom
# Residual deviance: 302.09  on 250  degrees of freedom
# AIC: 2365.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6389
#           Std. Err.:  0.0540
#
#  2 x log-likelihood:  -2359.5120
# ------------------------------------------------------------
# df$country: Spain
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7349982236, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.9679  -0.9661  -0.2055   0.3794   1.5692
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        5.438e+00  1.510e-01  36.007   <2e-16 ***
# gdp_per_capita.... 7.402e-06  6.594e-06   1.123    0.262
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.735) family taken to be 1)
#
#     Null deviance: 444.48  on 371  degrees of freedom
# Residual deviance: 443.26  on 370  degrees of freedom
# AIC: 4888.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7350
#           Std. Err.:  0.0474
#
#  2 x log-likelihood:  -4882.5560
# ------------------------------------------------------------
# df$country: Sweden
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.8307930333, link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.86575  -0.80802  -0.09103   0.20108   1.41980
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         4.870e+00  1.917e-01  25.396   <2e-16 ***
# gdp_per_capita.... -5.245e-06  4.456e-06  -1.177    0.239
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8308) family taken to be 1)
#
#     Null deviance: 411.25  on 347  degrees of freedom
# Residual deviance: 409.85  on 346  degrees of freedom
# AIC: 3937.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8308
#           Std. Err.:  0.0578
#
#  2 x log-likelihood:  -3931.7390
# ------------------------------------------------------------
# df$country: Switzerland
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7549190239, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7583  -0.9602  -0.1357   0.2548   1.2665
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.001e+00  2.578e-01  19.397   <2e-16 ***
# gdp_per_capita.... -5.738e-06  3.928e-06  -1.461    0.144
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7549) family taken to be 1)
#
#     Null deviance: 301.89  on 251  degrees of freedom
# Residual deviance: 299.82  on 250  degrees of freedom
# AIC: 2838
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7549
#           Std. Err.:  0.0617
#
#  2 x log-likelihood:  -2832.0330
# ------------------------------------------------------------
# df$country: Turkey
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 1.349026837, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8167  -1.2077  -0.4956   0.5462   1.8647
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        3.334e+00  9.892e-01   3.370 0.000751 ***
# gdp_per_capita.... 1.194e-04  8.113e-05   1.472 0.140978
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(1.349) family taken to be 1)
#
#     Null deviance: 95.501  on 83  degrees of freedom
# Residual deviance: 93.408  on 82  degrees of freedom
# AIC: 974.14
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.349
#           Std. Err.:  0.191
#
#  2 x log-likelihood:  -968.137
# ------------------------------------------------------------
# df$country: Turkmenistan
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7565475368, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3689  -1.1829  -0.4856   0.3676   2.3970
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         3.495e+00  8.837e-02  39.547  < 2e-16 ***
# gdp_per_capita.... -1.250e-04  2.411e-05  -5.185 2.16e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7565) family taken to be 1)
#
#     Null deviance: 426.55  on 347  degrees of freedom
# Residual deviance: 405.00  on 346  degrees of freedom
# AIC: 2906.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7565
#           Std. Err.:  0.0546
#
#  2 x log-likelihood:  -2900.2300
# ------------------------------------------------------------
# df$country: Ukraine
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.7280130207, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4219  -1.1153  -0.4028   0.2152   1.8044
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         7.125e+00  1.307e-01  54.528   <2e-16 ***
# gdp_per_capita.... -1.490e-04  6.101e-05  -2.442   0.0146 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.728) family taken to be 1)
#
#     Null deviance: 409.18  on 335  degrees of freedom
# Residual deviance: 403.11  on 334  degrees of freedom
# AIC: 5254
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7280
#           Std. Err.:  0.0482
#
#  2 x log-likelihood:  -5248.0420
# ------------------------------------------------------------
# df$country: United Kingdom
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.664953857, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.9040  -0.8754  -0.3324   0.3157   1.7462
#
# Coefficients:
#                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)         5.975e+00  1.719e-01  34.764   <2e-16 ***
# gdp_per_capita.... -2.122e-06  5.004e-06  -0.424    0.672
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.665) family taken to be 1)
#
#     Null deviance: 449.23  on 371  degrees of freedom
# Residual deviance: 449.04  on 370  degrees of freedom
# AIC: 5100.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6650
#           Std. Err.:  0.0424
#
#  2 x log-likelihood:  -5094.3290
# ------------------------------------------------------------
# df$country: Uzbekistan
#
# Call:
# glm.nb(formula = suicides_no ~ gdp_per_capita...., data = x,
#     init.theta = 0.9402941713, link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2236  -1.2582  -0.4074   0.5440   1.8174
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)        4.7516765  0.1266895  37.506   <2e-16 ***
# gdp_per_capita.... 0.0001300  0.0001122   1.159    0.246
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9403) family taken to be 1)
#
#     Null deviance: 306.33  on 263  degrees of freedom
# Residual deviance: 304.90  on 262  degrees of freedom
# AIC: 3111.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9403
#           Std. Err.:  0.0728
#
#  2 x log-likelihood:  -3105.2690

# %% [markdown]
# #### Negative Binomial by country for HDI

# %%
# Fitting the Negative binomial regression model by country using HDI as the independent variable
by(HDIdata,HDIdata$country,function(x) summary(glm.nb(suicides_no ~ HDI , data = x)))

#Again as so many of the models are statistically insignificant,
#not going to check the model assumptions as its evident it's not a good fit
# Out:
# HDIdata$country: Albania
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6447686779,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8331  -1.1365  -0.3135   0.3351   1.7423
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   2.5216     1.4348   1.757   0.0788 .
# HDI          -0.7096     2.1298  -0.333   0.7390
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6448) family taken to be 1)
#
#     Null deviance: 261.44  on 226  degrees of freedom
# Residual deviance: 261.35  on 225  degrees of freedom
# AIC: 1399.4
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6448
#           Std. Err.:  0.0698
#
#  2 x log-likelihood:  -1393.3570
# ------------------------------------------------------------
# HDIdata$country: Armenia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.9038765652,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0236  -1.1064  -0.4127   0.3579   1.9125
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   3.4781     0.8079   4.305 1.67e-05 ***
# HDI          -2.4334     1.2006  -2.027   0.0427 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9039) family taken to be 1)
#
#     Null deviance: 334.30  on 287  degrees of freedom
# Residual deviance: 329.97  on 286  degrees of freedom
# AIC: 1686.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9039
#           Std. Err.:  0.0902
#
#  2 x log-likelihood:  -1680.7800
# ------------------------------------------------------------
# HDIdata$country: Austria
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7267907452,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7823  -1.0338  -0.1615   0.2487   1.2569
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    7.862      1.597   4.923 8.54e-07 ***
# HDI           -3.580      1.875  -1.909   0.0563 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7268) family taken to be 1)
#
#     Null deviance: 375.78  on 311  degrees of freedom
# Residual deviance: 372.11  on 310  degrees of freedom
# AIC: 3616.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7268
#           Std. Err.:  0.0526
#
#  2 x log-likelihood:  -3610.6300
# ------------------------------------------------------------
# HDIdata$country: Azerbaijan
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7148701649,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9926  -0.9616  -0.5296   0.1830   2.8984
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -0.4551     2.3719  -0.192    0.848
# HDI           3.9777     3.6674   1.085    0.278
#
# (Dispersion parameter for Negative Binomial(0.7149) family taken to be 1)
#
#     Null deviance: 152.47  on 131  degrees of freedom
# Residual deviance: 151.66  on 130  degrees of freedom
# AIC: 837.05
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7149
#           Std. Err.:  0.0964
#
#  2 x log-likelihood:  -831.0510
# ------------------------------------------------------------
# HDIdata$country: Belarus
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6514204037,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2789  -1.0656  -0.4256   0.2971   1.7614
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.092      1.135   7.128 1.02e-12 ***
# HDI           -3.590      1.558  -2.305   0.0212 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6514) family taken to be 1)
#
#     Null deviance: 237.17  on 191  degrees of freedom
# Residual deviance: 232.16  on 190  degrees of freedom
# AIC: 2469.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6514
#           Std. Err.:  0.0571
#
#  2 x log-likelihood:  -2463.9160
# ------------------------------------------------------------
# HDIdata$country: Belgium
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7375102721,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8294  -0.9790  -0.1271   0.2526   1.5782
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept) 5.117378   1.912844   2.675  0.00747 **
# HDI         0.001142   2.184995   0.001  0.99958
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7375) family taken to be 1)
#
#     Null deviance: 372.18  on 311  degrees of freedom
# Residual deviance: 372.18  on 310  degrees of freedom
# AIC: 3806.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7375
#           Std. Err.:  0.0528
#
#  2 x log-likelihood:  -3800.2630
# ------------------------------------------------------------
# HDIdata$country: Bosnia and Herzegovina
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.5916208665,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1229  -0.7943  -0.7943   0.1116   1.2665
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -624.1      105.4  -5.921 3.19e-09 ***
# HDI            689.5      116.1   5.941 2.84e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5916) family taken to be 1)
#
#     Null deviance: 55.666  on 23  degrees of freedom
# Residual deviance: 22.883  on 22  degrees of freedom
# AIC: 127.23
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.592
#           Std. Err.:  0.224
#
#  2 x log-likelihood:  -121.228
# ------------------------------------------------------------
# HDIdata$country: Bulgaria
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.808494647,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8211  -1.1073  -0.2414   0.3423   1.4724
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    9.497      1.302   7.295 2.98e-13 ***
# HDI           -6.735      1.769  -3.807  0.00014 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8085) family taken to be 1)
#
#     Null deviance: 368.73  on 299  degrees of freedom
# Residual deviance: 354.85  on 298  degrees of freedom
# AIC: 3328.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8085
#           Std. Err.:  0.0603
#
#  2 x log-likelihood:  -3322.6460
# ------------------------------------------------------------
# HDIdata$country: Croatia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7180665355,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5889  -1.1428  -0.2404   0.1624   1.3678
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    6.309      1.450   4.351 1.36e-05 ***
# HDI           -2.647      1.861  -1.422    0.155
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7181) family taken to be 1)
#
#     Null deviance: 302.07  on 251  degrees of freedom
# Residual deviance: 300.06  on 250  degrees of freedom
# AIC: 2637.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7181
#           Std. Err.:  0.0586
#
#  2 x log-likelihood:  -2631.3360
# ------------------------------------------------------------
# HDIdata$country: Cyprus
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6418458157,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6413  -1.2382  -0.6363   0.3278   2.7087
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -33.478      5.994  -5.585 2.34e-08 ***
# HDI           40.512      7.090   5.714 1.10e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6418) family taken to be 1)
#
#     Null deviance: 200.84  on 167  degrees of freedom
# Residual deviance: 167.23  on 166  degrees of freedom
# AIC: 628.31
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.642
#           Std. Err.:  0.117
#
#  2 x log-likelihood:  -622.313
# ------------------------------------------------------------
# HDIdata$country: Czech Republic
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6890452759,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7338  -1.1040  -0.2335   0.1300   1.6145
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    6.291      1.074   5.857 4.72e-09 ***
# HDI           -1.710      1.324  -1.291    0.197
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.689) family taken to be 1)
#
#     Null deviance: 375.96  on 311  degrees of freedom
# Residual deviance: 374.24  on 310  degrees of freedom
# AIC: 3664.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6890
#           Std. Err.:  0.0491
#
#  2 x log-likelihood:  -3658.5440
# ------------------------------------------------------------
# HDIdata$country: Denmark
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6772362683,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5310  -1.0657  -0.2580   0.2178   1.5719
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.015      2.009   3.990  6.6e-05 ***
# HDI           -4.471      2.262  -1.976   0.0481 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6772) family taken to be 1)
#
#     Null deviance: 321.40  on 263  degrees of freedom
# Residual deviance: 317.27  on 262  degrees of freedom
# AIC: 2651.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6772
#           Std. Err.:  0.0558
#
#  2 x log-likelihood:  -2645.6020
# ------------------------------------------------------------
# HDIdata$country: Estonia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.726797695,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4895  -1.1693  -0.3312   0.1602   1.7248
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    9.361      1.371   6.828 8.64e-12 ***
# HDI           -7.501      1.687  -4.446 8.74e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7268) family taken to be 1)
#
#     Null deviance: 318.44  on 251  degrees of freedom
# Residual deviance: 297.86  on 250  degrees of freedom
# AIC: 2154.4
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7268
#           Std. Err.:  0.0631
#
#  2 x log-likelihood:  -2148.4260
# ------------------------------------------------------------
# HDIdata$country: Finland
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6777237836,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6683  -0.9696  -0.2979   0.2493   1.6794
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.070      1.343   6.009 1.86e-09 ***
# HDI           -4.097      1.553  -2.638  0.00835 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6777) family taken to be 1)
#
#     Null deviance: 381.58  on 311  degrees of freedom
# Residual deviance: 374.63  on 310  degrees of freedom
# AIC: 3430.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6777
#           Std. Err.:  0.0494
#
#  2 x log-likelihood:  -3424.5920
# ------------------------------------------------------------
# HDIdata$country: France
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7062928338,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6515  -1.0640  -0.1800   0.2617   1.4498
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.553      2.010   4.256 2.08e-05 ***
# HDI           -2.081      2.377  -0.875    0.381
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7063) family taken to be 1)
#
#     Null deviance: 361.67  on 299  degrees of freedom
# Residual deviance: 360.91  on 298  degrees of freedom
# AIC: 4656.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7063
#           Std. Err.:  0.0495
#
#  2 x log-likelihood:  -4650.5550
# ------------------------------------------------------------
# HDIdata$country: Georgia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8032165332,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1387  -1.1437  -0.3842   0.3520   2.1384
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -0.394      2.152  -0.183    0.855
# HDI            3.842      2.967   1.295    0.195
#
# (Dispersion parameter for Negative Binomial(0.8032) family taken to be 1)
#
#     Null deviance: 181.43  on 155  degrees of freedom
# Residual deviance: 179.58  on 154  degrees of freedom
# AIC: 1073.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8032
#           Std. Err.:  0.0962
#
#  2 x log-likelihood:  -1067.8750
# ------------------------------------------------------------
# HDIdata$country: Germany
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7211155427,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5043  -1.1529  -0.1399   0.1967   1.3421
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    9.228      1.387   6.652 2.89e-11 ***
# HDI           -2.727      1.577  -1.729   0.0838 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7211) family taken to be 1)
#
#     Null deviance: 377.51  on 311  degrees of freedom
# Residual deviance: 374.45  on 310  degrees of freedom
# AIC: 4868.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7211
#           Std. Err.:  0.0496
#
#  2 x log-likelihood:  -4862.9130
# ------------------------------------------------------------
# HDIdata$country: Greece
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6673267709,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3200  -1.0176  -0.3755   0.3158   1.6630
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    1.798      1.431   1.256    0.209
# HDI            2.088      1.753   1.191    0.234
#
# (Dispersion parameter for Negative Binomial(0.6673) family taken to be 1)
#
#     Null deviance: 375.77  on 311  degrees of freedom
# Residual deviance: 374.31  on 310  degrees of freedom
# AIC: 2794.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6673
#           Std. Err.:  0.0523
#
#  2 x log-likelihood:  -2788.9410
# ------------------------------------------------------------
# HDIdata$country: Hungary
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.5826947425,
#     link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.68936  -1.15425  -0.23574   0.06265   1.48653
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    9.226      1.426   6.469 9.84e-11 ***
# HDI           -4.807      1.819  -2.643  0.00822 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5827) family taken to be 1)
#
#     Null deviance: 374.04  on 299  degrees of freedom
# Residual deviance: 367.06  on 298  degrees of freedom
# AIC: 3819.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5827
#           Std. Err.:  0.0416
#
#  2 x log-likelihood:  -3813.2870
# ------------------------------------------------------------
# HDIdata$country: Iceland
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8501772359,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6418  -1.5465  -0.3267   0.3869   1.8470
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -0.9212     1.7058  -0.540    0.589
# HDI           2.2815     1.9586   1.165    0.244
#
# (Dispersion parameter for Negative Binomial(0.8502) family taken to be 1)
#
#     Null deviance: 348.98  on 311  degrees of freedom
# Residual deviance: 347.58  on 310  degrees of freedom
# AIC: 1388.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.850
#           Std. Err.:  0.103
#
#  2 x log-likelihood:  -1382.735
# ------------------------------------------------------------
# HDIdata$country: Ireland
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6766980728,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3789  -1.2126  -0.5528   0.4725   1.6845
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    1.585      1.198   1.323   0.1859
# HDI            2.381      1.402   1.699   0.0894 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6767) family taken to be 1)
#
#     Null deviance: 359.25  on 299  degrees of freedom
# Residual deviance: 356.50  on 298  degrees of freedom
# AIC: 2754.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6767
#           Std. Err.:  0.0516
#
#  2 x log-likelihood:  -2748.8700
# ------------------------------------------------------------
# HDIdata$country: Israel
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 1.001366191,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6582  -0.9584  -0.2827   0.4949   1.7653
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    2.386      1.527   1.563    0.118
# HDI            1.244      1.781   0.699    0.485
#
# (Dispersion parameter for Negative Binomial(1.0014) family taken to be 1)
#
#     Null deviance: 364.35  on 311  degrees of freedom
# Residual deviance: 363.87  on 310  degrees of freedom
# AIC: 2793.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.0014
#           Std. Err.:  0.0792
#
#  2 x log-likelihood:  -2787.8010
# ------------------------------------------------------------
# HDIdata$country: Italy
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7056996977,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.9510  -1.0724  -0.1759   0.3447   1.3902
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    7.101      1.612   4.406 1.06e-05 ***
# HDI           -1.487      1.926  -0.772     0.44
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7057) family taken to be 1)
#
#     Null deviance: 374.64  on 311  degrees of freedom
# Residual deviance: 374.04  on 310  degrees of freedom
# AIC: 4258.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7057
#           Std. Err.:  0.0491
#
#  2 x log-likelihood:  -4252.8610
# ------------------------------------------------------------
# HDIdata$country: Kazakhstan
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8717538865,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2308  -1.1738  -0.6326   0.4993   1.8892
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   6.9821     0.9415   7.416 1.21e-13 ***
# HDI          -1.6596     1.2996  -1.277    0.202
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8718) family taken to be 1)
#
#     Null deviance: 366.68  on 311  degrees of freedom
# Residual deviance: 365.11  on 310  degrees of freedom
# AIC: 4235.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8718
#           Std. Err.:  0.0610
#
#  2 x log-likelihood:  -4229.1700
# ------------------------------------------------------------
# HDIdata$country: Kyrgyzstan
# NULL
# ------------------------------------------------------------
# HDIdata$country: Latvia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6428452371,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4958  -1.1058  -0.3197   0.1639   1.5634
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.019      1.113   7.203 5.87e-13 ***
# HDI           -5.330      1.430  -3.726 0.000195 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6428) family taken to be 1)
#
#     Null deviance: 316.66  on 251  degrees of freedom
# Residual deviance: 302.39  on 250  degrees of freedom
# AIC: 2440.4
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6428
#           Std. Err.:  0.0536
#
#  2 x log-likelihood:  -2434.4450
# ------------------------------------------------------------
# HDIdata$country: Lithuania
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6522606569,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6200  -1.1144  -0.4065   0.1330   1.8848
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.187      1.336   6.130  8.8e-10 ***
# HDI           -4.447      1.682  -2.644  0.00819 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6523) family taken to be 1)
#
#     Null deviance: 309.43  on 251  degrees of freedom
# Residual deviance: 302.56  on 250  degrees of freedom
# AIC: 2828.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6523
#           Std. Err.:  0.0511
#
#  2 x log-likelihood:  -2822.6300
# ------------------------------------------------------------
# HDIdata$country: Luxembourg
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8732433266,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9058  -1.0434  -0.3366   0.3304   2.0312
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    3.649      1.613   2.263   0.0236 *
# HDI           -2.325      1.878  -1.238   0.2157
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8732) family taken to be 1)
#
#     Null deviance: 359.55  on 311  degrees of freedom
# Residual deviance: 358.05  on 310  degrees of freedom
# AIC: 1716.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8732
#           Std. Err.:  0.0884
#
#  2 x log-likelihood:  -1710.5300
# ------------------------------------------------------------
# HDIdata$country: Malta
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6669487903,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4749  -1.2523  -0.4189   0.3309   2.2646
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -4.803      1.662  -2.890  0.00385 **
# HDI            6.626      2.054   3.225  0.00126 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6669) family taken to be 1)
#
#     Null deviance: 325.70  on 311  degrees of freedom
# Residual deviance: 315.62  on 310  degrees of freedom
# AIC: 1112
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6669
#           Std. Err.:  0.0911
#
#  2 x log-likelihood:  -1105.9790
# ------------------------------------------------------------
# HDIdata$country: Montenegro
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.2825771392,
#     link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -1.47067  -1.08333  -0.96515   0.01389   2.07635
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -35.040      9.747  -3.595 0.000324 ***
# HDI           47.752     12.727   3.752 0.000175 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.2826) family taken to be 1)
#
#     Null deviance: 89.335  on 83  degrees of freedom
# Residual deviance: 78.164  on 82  degrees of freedom
# AIC: 403.57
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.2826
#           Std. Err.:  0.0587
#
#  2 x log-likelihood:  -397.5680
# ------------------------------------------------------------
# HDIdata$country: Netherlands
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7969481717,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8622  -0.8376  -0.3037   0.3989   1.6251
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    3.773      1.930   1.955   0.0506 .
# HDI            1.251      2.183   0.573   0.5665
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7969) family taken to be 1)
#
#     Null deviance: 368.55  on 311  degrees of freedom
# Residual deviance: 368.21  on 310  degrees of freedom
# AIC: 3666.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7969
#           Std. Err.:  0.0576
#
#  2 x log-likelihood:  -3660.3050
# ------------------------------------------------------------
# HDIdata$country: Norway
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.9290813112,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7311  -0.9089  -0.2559   0.3726   1.5717
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    5.143      1.797   2.861  0.00422 **
# HDI           -1.436      1.966  -0.730  0.46510
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.9291) family taken to be 1)
#
#     Null deviance: 366.83  on 311  degrees of freedom
# Residual deviance: 366.27  on 310  degrees of freedom
# AIC: 3026.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.9291
#           Std. Err.:  0.0717
#
#  2 x log-likelihood:  -3020.1720
# ------------------------------------------------------------
# HDIdata$country: Poland
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6410573245,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2610  -1.1544  -0.4610   0.2572   1.7615
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    5.507      1.238   4.448 8.65e-06 ***
# HDI            0.849      1.560   0.544    0.586
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6411) family taken to be 1)
#
#     Null deviance: 351.15  on 287  degrees of freedom
# Residual deviance: 350.85  on 286  degrees of freedom
# AIC: 4097.3
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6411
#           Std. Err.:  0.0454
#
#  2 x log-likelihood:  -4091.2520
# ------------------------------------------------------------
# HDIdata$country: Portugal
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6442823888,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.5150  -1.0654  -0.2812   0.3018   1.4556
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    1.994      1.649   1.209    0.227
# HDI            2.938      2.097   1.401    0.161
#
# (Dispersion parameter for Negative Binomial(0.6443) family taken to be 1)
#
#     Null deviance: 320.42  on 263  degrees of freedom
# Residual deviance: 318.25  on 262  degrees of freedom
# AIC: 2776
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6443
#           Std. Err.:  0.0519
#
#  2 x log-likelihood:  -2770.0060
# ------------------------------------------------------------
# HDIdata$country: Romania
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7183967319,
#     link = log)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.87612  -1.15347  -0.36596  -0.01538   1.89323
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   6.0106     1.0490   5.730    1e-08 ***
# HDI          -0.8424     1.4160  -0.595    0.552
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7184) family taken to be 1)
#
#     Null deviance: 373.63  on 311  degrees of freedom
# Residual deviance: 373.29  on 310  degrees of freedom
# AIC: 3968.7
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7184
#           Std. Err.:  0.0499
#
#  2 x log-likelihood:  -3962.6510
# ------------------------------------------------------------
# HDIdata$country: Russian Federation
# NULL
# ------------------------------------------------------------
# HDIdata$country: San Marino
# NULL
# ------------------------------------------------------------
# HDIdata$country: Serbia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.5733866476,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4838  -1.0369  -0.2052   0.2919   1.1811
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    7.322      2.560   2.860  0.00423 **
# HDI           -3.495      3.429  -1.019  0.30800
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.5734) family taken to be 1)
#
#     Null deviance: 264.38  on 215  degrees of freedom
# Residual deviance: 263.35  on 214  degrees of freedom
# AIC: 2431.6
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.5734
#           Std. Err.:  0.0508
#
#  2 x log-likelihood:  -2425.6120
# ------------------------------------------------------------
# HDIdata$country: Slovakia
# NULL
# ------------------------------------------------------------
# HDIdata$country: Slovenia
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6378709015,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.3465  -1.0549  -0.3051   0.1020   1.5719
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    7.035      1.985   3.544 0.000395 ***
# HDI           -3.885      2.334  -1.665 0.095949 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6379) family taken to be 1)
#
#     Null deviance: 304.84  on 251  degrees of freedom
# Residual deviance: 302.12  on 250  degrees of freedom
# AIC: 2366
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6379
#           Std. Err.:  0.0539
#
#  2 x log-likelihood:  -2359.9560
# ------------------------------------------------------------
# HDIdata$country: Spain
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7107727251,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.9259  -0.9599  -0.2049   0.3811   1.4952
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    4.236      1.535   2.759   0.0058 **
# HDI            1.667      1.849   0.902   0.3673
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7108) family taken to be 1)
#
#     Null deviance: 374.01  on 311  degrees of freedom
# Residual deviance: 373.21  on 310  degrees of freedom
# AIC: 4111.9
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7108
#           Std. Err.:  0.0499
#
#  2 x log-likelihood:  -4105.8770
# ------------------------------------------------------------
# HDIdata$country: Sweden
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8484106437,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8940  -0.8097  -0.1116   0.2001   1.4166
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    6.502      1.666   3.904 9.46e-05 ***
# HDI           -2.117      1.878  -1.127     0.26
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8484) family taken to be 1)
#
#     Null deviance: 367.48  on 311  degrees of freedom
# Residual deviance: 366.16  on 310  degrees of freedom
# AIC: 3514.8
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8484
#           Std. Err.:  0.0623
#
#  2 x log-likelihood:  -3508.8260
# ------------------------------------------------------------
# HDIdata$country: Switzerland
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7545265692,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.7826  -0.9470  -0.1382   0.2654   1.2858
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    7.926      2.340   3.388 0.000705 ***
# HDI           -3.636      2.587  -1.405 0.159918
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7545) family taken to be 1)
#
#     Null deviance: 301.75  on 251  degrees of freedom
# Residual deviance: 299.83  on 250  degrees of freedom
# AIC: 2838.2
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7545
#           Std. Err.:  0.0617
#
#  2 x log-likelihood:  -2832.1890
# ------------------------------------------------------------
# HDIdata$country: Turkey
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 1.343553239,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7698  -1.1868  -0.4406   0.5421   1.9290
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    1.051      2.812   0.374    0.709
# HDI            4.876      3.670   1.329    0.184
#
# (Dispersion parameter for Negative Binomial(1.3436) family taken to be 1)
#
#     Null deviance: 95.121  on 83  degrees of freedom
# Residual deviance: 93.445  on 82  degrees of freedom
# AIC: 974.55
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.344
#           Std. Err.:  0.190
#
#  2 x log-likelihood:  -968.547
# ------------------------------------------------------------
# HDIdata$country: Turkmenistan
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6230506324,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9591  -1.2220  -0.5141   0.4546   1.3225
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    8.748     11.171   0.783    0.434
# HDI           -9.195     16.241  -0.566    0.571
#
# (Dispersion parameter for Negative Binomial(0.6231) family taken to be 1)
#
#     Null deviance: 83.953  on 71  degrees of freedom
# Residual deviance: 83.603  on 70  degrees of freedom
# AIC: 497.71
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.623
#           Std. Err.:  0.111
#
#  2 x log-likelihood:  -491.707
# ------------------------------------------------------------
# HDIdata$country: Ukraine
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.7255035383,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.4048  -1.0900  -0.3705   0.2432   1.7031
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   11.683      1.652   7.073 1.52e-12 ***
# HDI           -6.886      2.352  -2.927  0.00342 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.7255) family taken to be 1)
#
#     Null deviance: 368.58  on 299  degrees of freedom
# Residual deviance: 360.09  on 298  degrees of freedom
# AIC: 4694.5
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.7255
#           Std. Err.:  0.0508
#
#  2 x log-likelihood:  -4688.4610
# ------------------------------------------------------------
# HDIdata$country: United Kingdom
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.6615903478,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.8921  -0.9011  -0.3448   0.3071   1.7330
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   6.0314     1.5380   3.922  8.8e-05 ***
# HDI          -0.1613     1.7721  -0.091    0.927
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.6616) family taken to be 1)
#
#     Null deviance: 377.08  on 311  degrees of freedom
# Residual deviance: 377.07  on 310  degrees of freedom
# AIC: 4268
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.6616
#           Std. Err.:  0.0460
#
#  2 x log-likelihood:  -4261.9610
# ------------------------------------------------------------
# HDIdata$country: Uzbekistan
#
# Call:
# glm.nb(formula = suicides_no ~ HDI, data = x, init.theta = 0.8809376753,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1039  -1.3638  -0.3779   0.5767   1.7360
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)    4.014      1.694   2.370   0.0178 *
# HDI            1.400      2.625   0.533   0.5938
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(0.8809) family taken to be 1)
#
#     Null deviance: 167.89  on 143  degrees of freedom
# Residual deviance: 167.57  on 142  degrees of freedom
# AIC: 1709.4
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  0.8809
#           Std. Err.:  0.0917
#
#  2 x log-likelihood:  -1703.4170

# %% [markdown]
# It's not optimal to do the averaged suicide rate for the Negative Binomial Regression as it prefers larger data sets and the averaged data would not have enough points.
